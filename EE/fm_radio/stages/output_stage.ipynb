# %% [markdown]
# - Stereo headphone jacks have 3 or more ports.
# - https://www.cuidevices.com/blog/understanding-audio-jack-switches-and-schematics
# - The following link has 3 ports, but 4 pins (the two tip pins are connected to each other):
#     - https://www.digikey.com/en/products/detail/cui-devices/SJ1-2503A/738680
#     - In order from lowest to highest, these ports are: sleeve, tip, tip, ring.
#     - ![image.png](attachment:image.png)
#     - There are no switches present here.
# - All of the types of cables (TRS, TS, TRRS, etc.) are interchangeable, although they won't have full functionality.
# - Which port corresponds to ground and which correspond to signal?
#     - According to https://www.ac3filter.net/is-tip-or-sleeve-ground/, the sleeve is ground and tip is the left and ring is the right.
