# %% [markdown]
# - Simulation producing a wave of around half the frequency of the original
# - Checking voltage across L4, this is what I got
# - ![image.png](attachment:image.png)

# %% [markdown]
# - Frequency is around 10x of input wave
# - The reason the phase is always 0 is because there's no resistance!!! Add resistance to add a real part to make the phase work as expected!

# %% [markdown]
# - The output voltage (across the capacitor on the right) is 90 degrees out of phase with the input when the input is 10.7 MHz, and 0 degrees when the input frequency is below 10.7 MHz, and 180 degrees when the input frequency is above 10.7 Mhz.
# ![image.png](attachment:image.png)

# %% [markdown]
# - This doesn't make sense since the phase should go to 0 at higher frequencies.
# - Looks like the video I was following didn't take into account the negative sign in the expression for the voltage across C3 in the schematic above. So, the frequency should actually shift towards -180 at high frequencies, not 0.
# - Figured out the problem - The equation he's using in the video is incorrect. the capacitor impedance should be -j/wC, not j/wC.

# %% [markdown]
# ![image.png](attachment:image.png)
# - For some reason the phase is 180 at resonance in the transient sim after some time, despite the math and the AC sim saying it should be 90 degrees.

# %% [markdown]
# - Figured out the problem - has to do with initial conditions. my math doesn't account for that. https://www.youtube.com/watch?v=q90Lh8HELjo
# - This can be solved by putting a resistor to damp the ringing.
