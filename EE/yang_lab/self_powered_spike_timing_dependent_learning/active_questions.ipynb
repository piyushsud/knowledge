# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q: In the above picture, is Vpre the same as WGFMU1 and Vpost the same as WGFMU2?
# A:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q: How does competition based learning work in the above picture? Is the change in resistance proportional to the voltage difference of WFGMU1 and WGFMU2?
# A:

# %% [markdown]
# Does the pressure sensor have to not have a power supply (be entirely self powered)?
