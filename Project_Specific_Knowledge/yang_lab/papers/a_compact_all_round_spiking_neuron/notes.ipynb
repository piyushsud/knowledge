# %% [markdown]
# Abstract
# - Emulated neuron demonstrates 6 characteristics of biological neurons
# - Spiking neural network with memristor based neurons => better energy and area efficiency

# %% [markdown]
# Introduction
# - The brain is more efficient because it uses:
#     - analog processing
#     - asynchronous operation
#     - spike based information
#     - in-memory computing
#     - rich neuron functionalities
# - Previously, neurons have been oversimplified or have used lots of peripheral circuits
# - Digital circuits require analog to digital converters which are very inefficient
# - Some researchers are working on analog & asynchronous circuits using analog CMOS
#     - This doesn't really work though because transistors and biological neurons have very different dynamics
# - Memristors are being developed with increasingly rich dynamics
#     - Short term memory
#     - Negative differential resistance used to model neuron oscillations
#
# Asymmetric Diffusive Memristor
#
# - Silver was used here to form conduction channels
# - When an external voltage source is applied, drift occurs due to the Ag atoms oxidizing into Ag+ ions at the top electrode, which drift to the bottom electrode and turn back into Ag atoms, forming a conduction channel.
# - Drift and diffusion compete - drift causes the conduction channel to form and diffusion causes the channel to break apart. When the voltage is high enough, drift dominates diffusion, and vice versa. When the voltage is low or negative, the device goes to the HRS, but when it's high, the device goes to the LRS.
# - After switching a few times, the Ag forms a "residue" inside the conduction channel which makes it easier to switch on the device. However, after a long enough time, this residue dissolves and returns to the Ag reservoir.
# - HfO2 and SiO2 were both evaluated for the ideal memristor. It seems like the HfO2 memristor has a higher threshold voltage (0.9V vs. 0.15V) and a higher OFF state resistance (0.7 Tohms vs. 1.5 Gohms), so it's better for 1M1T1R neurons and therefore is used for this paper.
#
# 1M1T1R Neuron and It's Functionalities
# - ![image.png](attachment:image.png)
# - The gate and source of the transistors are connected via a control resistor
# - During integration, the resistance of the memristor is much higher than that of the control resistor, so the voltage at the gate is very low, causing the nmos to be off and the output voltage to be high.
# - When the memristor turns on, the resistance rapidly drops and the nmos turns on (firing phase), reducing the output voltage.
# - After the firing phase, due to the low resistance of the memristor, there is a very small voltage difference across the memristor, so it gradually turns off - this is known as the refractory period. Due to the accumulated charge on the gate, the memristor is unable to switch on until it leaks away through the control resistor.
# - The memristor demonstrates intrinsic plasticity (relatively long short-term memory).
#     - Examples of intrinsic plasticity include adaptation (decreased excitability after firing) or sensitization (increased excitability after firing)
#     - This memristor demonstrates increased excitability in our case.
# ![image-2.png](attachment:image-2.png)
# - It also demonstrates stochasticity (randomness) in the length of the refractory period.
# - Each characteristic was demonstrated individually as well.
#     - Leaky integration was demonstrated by showing that longer pulse intervals required more pulses to fire since charge would leak during the pulse.
#     -
